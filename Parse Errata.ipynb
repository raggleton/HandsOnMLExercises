# %% [markdown]
# Parse the book errata for easier sorting

# %%
import bisect
from collections import OrderedDict
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.oreilly.com/catalog/errata.csp?isbn=0636920142874')
soup = BeautifulSoup(r.text)

# %%
soup.title.text
# Out:
# "Errata | O'Reilly Media Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow"

# %%
t = soup.find('table')

# %%
t.attrs.get('class', '')
# Out:
# ['mainLayoutTable']

# %%
errata_table = None
for t in soup.find_all('table', recursive=True):
    if 'class' not in t.attrs:
        errata_table = t
        break

# %%
data = []
for tr in errata_table.find_all('tr'):
    cols = [c for c in tr.find_all('td')]
    if len(cols) == 0:
        continue
    col_texts = [c.text.strip().replace('\r', '') for c in cols]
    if len(col_texts) == 6:
        data.append(col_texts)
    else:
        print('found != 6 cols')
        print(col_texts)

# %%
df = pd.DataFrame(data, columns=['Version', 'Location', 'Description', 'Submitted By', 'Date Submitted', 'Date Corrected'])

# %%
df.dtypes
# Out:
# Version           object
# Location          object
# Description       object
# Submitted By      object
# Date Submitted    object
# Date Corrected    object
# dtype: object

# %%
df['Version'] = df['Version'].astype('category')

# %%
df['Version'].cat.categories
# Out:
# Index(['Mobi', 'Other Digital Version', 'PDF', 'Printed', 'Printed, PDF',
#        'Printed, Safari Books Online', 'Safari Books Online', 'ePub',
#        'ePub, Mobi, Safari Books Online'],
#       dtype='object')

# %%
df['Date Submitted'] = pd.to_datetime(df['Date Submitted'])
df['Date Corrected'] = pd.to_datetime(df['Date Corrected'])

# %%
# extract chapter number, if one exists. If not, set to -1
# the ?: at the start makes it a non-capturing group
# use float type to handle NaNs
df['Chapter'] = df['Location'].str.extract('(?:Ch|ch|chapter|Chapter)\.? ?([0-9]+)').astype('float')
descr_ch = df['Description'].str.extract('(?<!Mar)(?:Ch|ch|chapter|Chapter)\.? ?([0-9]{1,3})', expand=False).astype('float')  # the (?<!Mar) is to avoid matching "March"
df['Chapter'] = df['Chapter'].fillna(descr_ch)
df['Chapter'][df['Chapter'].isna()] = -1
df['Chapter'] = df['Chapter'].astype('int')
# Out:
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/pandas/core/series.py:990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# extract page number, if one exists. If not, set to -1
# the ?: at the start makes it a non-capturing group
# use float type to handle NaNs
df['Page'] = df['Location'].str.extract('(?:p|page|Page)\.? ?([0-9]+)').astype('float')

# sometime get page number at start...make 3 digits to avoid cases where it's a chapter number instead
# FIXME use lookahead for "Chapter"? Not working though
df['Page'][df['Page'].isna()] = df[df['Page'].isna()]['Location'].str.extract('^([0-9]+)(?!.*(Ch))')[0].astype('float')

# Remove rows that refer to roman indices, to make life easier
roman_page = df['Location'].str.extract('(?:p|page|Page)\.? ?([xiv]+)(?![a-z])', expand=False)
roman_mask = ~(roman_page.isna())
df.drop(df[roman_mask].index, axis=0, inplace=True)

df['Page'].iloc[df['Page'].isna()] = -1
df['Page'] = df['Page'].astype('int')
# df['Page'][df['Page'] > 820] = -1  # book only has 820 pages
# Out:
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/pandas/core/series.py:990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/pandas/core/frame.py:4312: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
chapter_page_map = OrderedDict({
    1: 1,
    2: 35,
    3: 85,
    4: 111,
    5: 153,
    6: 175,
    7: 189,
    8: 213,
    9: 235,
    10: 279,
    11: 331,
    12: 375,
    13: 413,
    14: 445,
    15: 497,
    16: 525,
    17: 567,
    18: 609,
    19: 667
})

# %%
chapters = list(chapter_page_map.keys())
pages = list(chapter_page_map.values())

# %%
# find the chapter numbers for rows with page numbers but no chapter numbers
def lookup_chapter(row):
    ind = bisect.bisect_right(pages, row.Page) - 1
    return chapters[ind]

missing_ch_mask = (df['Chapter'] < 0) & (df['Page'] > 0)
df['Chapter'][missing_ch_mask] = df[missing_ch_mask].apply(lookup_chapter, axis=1)
# Out:
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/robin/.virtualenvs/handsonml/lib/python3.7/site-packages/pandas/core/series.py:990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
# Reorder columns, drop other info
df = df[['Version', 'Chapter', 'Page', 'Location', 'Description']]

# %%
df.query('Chapter < 0 & Page < 0')
# Out:
#                 Version  Chapter  Page  \
# 4   Safari Books Online       -1    -1
# 5   Safari Books Online       -1    -1
# 15  Safari Books Online       -1    -1
#
#                                              Location  \
# 4      ?\nSection: Computing Gradients Using Autodiff
# 5   "Changes in the Second Edition," Numbered List...
# 15  ??\nRight under "Training and Evaluating the M...
#
#                                           Description
# 4   Super minor typo: just replace\n\nyou must cal...
# 5   'covolutional' should be 'convolutional' (miss...
# 15  When I fit the model (including on Google Cola...

# %%
from IPython.display import display, HTML

# %%
df_sorted = df.sort_values(by=['Chapter', 'Page'])

# %%
df_styler = df_sorted.style.set_properties(**{
    'text-align': 'left', # left align text
    'white-space': 'pre-wrap', # make newlines work!
    'font-family': 'Arial',
    'font-size': '11pt',
})
df_styler.set_table_attributes('border="1"');
df_styler.hide_index();

# %%
# save to HTML
with open("my_errata.html", "w") as f:
    f.write("""<!DOCTYPE html>
<html>
<body>
""")
    f.write(df_styler.render(index=False))
    f.write("""
</body>
</html>""")

# %%
# from https://stackoverflow.com/questions/49661018/displaying-embedded-newlines-in-a-text-column-of-a-pandas-dataframe
display(df_sorted.style.set_properties(**{
    'text-align': 'left', # left align text
    'white-space': 'pre-wrap', # make newlines work!
}))
# Out:
# <style  type="text/css" >
# #T_a6bfb_row0_col0,#T_a6bfb_row0_col1,#T_a6bfb_row0_col2,#T_a6bfb_row0_col3,#T_a6bfb_row0_col4,#T_a6bfb_row1_col0,#T_a6bfb_row1_col1,#T_a6bfb_row1_col2,#T_a6bfb_row1_col3,#T_a6bfb_row1_col4,#T_a6bfb_row2_col0,#T_a6bfb_row2_col1,#T_a6bfb_row2_col2,#T_a6bfb_row2_col3,#T_a6bfb_row2_col4,#T_a6bfb_row3_col0,#T_a6bfb_row3_col1,#T_a6bfb_row3_col2,#T_a6bfb_row3_col3,#T_a6bfb_row3_col4,#T_a6bfb_row4_col0,#T_a6bfb_row4_col1,#T_a6bfb_row4_col2,#T_a6bfb_row4_col3,#T_a6bfb_row4_col4,#T_a6bfb_row5_col0,#T_a6bfb_row5_col1,#T_a6bfb_row5_col2,#T_a6bfb_row5_col3,#T_a6bfb_row5_col4,#T_a6bfb_row6_col0,#T_a6bfb_row6_col1,#T_a6bfb_row6_col2,#T_a6bfb_row6_col3,#T_a6bfb_row6_col4,#T_a6bfb_row7_col0,#T_a6bfb_row7_col1,#T_a6bfb_row7_col2,#T_a6bfb_row7_col3,#T_a6bfb_row7_col4,#T_a6bfb_row8_col0,#T_a6bfb_row8_col1,#T_a6bfb_row8_col2,#T_a6bfb_row8_col3,#T_a6bfb_row8_col4,#T_a6bfb_row9_col0,#T_a6bfb_row9_col1,#T_a6bfb_row9_col2,#T_a6bfb_row9_col3,#T_a6bfb_row9_col4,#T_a6bfb_row10_col0,#T_a6bfb_row10_col1,#T_a6bfb_row10_col2,#T_a6bfb_row10_col3,#T_a6bfb_row10_col4,#T_a6bfb_row11_col0,#T_a6bfb_row11_col1,#T_a6bfb_row11_col2,#T_a6bfb_row11_col3,#T_a6bfb_row11_col4,#T_a6bfb_row12_col0,#T_a6bfb_row12_col1,#T_a6bfb_row12_col2,#T_a6bfb_row12_col3,#T_a6bfb_row12_col4,#T_a6bfb_row13_col0,#T_a6bfb_row13_col1,#T_a6bfb_row13_col2,#T_a6bfb_row13_col3,#T_a6bfb_row13_col4,#T_a6bfb_row14_col0,#T_a6bfb_row14_col1,#T_a6bfb_row14_col2,#T_a6bfb_row14_col3,#T_a6bfb_row14_col4,#T_a6bfb_row15_col0,#T_a6bfb_row15_col1,#T_a6bfb_row15_col2,#T_a6bfb_row15_col3,#T_a6bfb_row15_col4,#T_a6bfb_row16_col0,#T_a6bfb_row16_col1,#T_a6bfb_row16_col2,#T_a6bfb_row16_col3,#T_a6bfb_row16_col4,#T_a6bfb_row17_col0,#T_a6bfb_row17_col1,#T_a6bfb_row17_col2,#T_a6bfb_row17_col3,#T_a6bfb_row17_col4,#T_a6bfb_row18_col0,#T_a6bfb_row18_col1,#T_a6bfb_row18_col2,#T_a6bfb_row18_col3,#T_a6bfb_row18_col4,#T_a6bfb_row19_col0,#T_a6bfb_row19_col1,#T_a6bfb_row19_col2,#T_a6bfb_row19_col3,#T_a6bfb_row19_col4,#T_a6bfb_row20_col0,#T_a6bfb_row20_col1,#T_a6bfb_row20_col2,#T_a6bfb_row20_col3,#T_a6bfb_row20_col4,#T_a6bfb_row21_col0,#T_a6bfb_row21_col1,#T_a6bfb_row21_col2,#T_a6bfb_row21_col3,#T_a6bfb_row21_col4,#T_a6bfb_row22_col0,#T_a6bfb_row22_col1,#T_a6bfb_row22_col2,#T_a6bfb_row22_col3,#T_a6bfb_row22_col4,#T_a6bfb_row23_col0,#T_a6bfb_row23_col1,#T_a6bfb_row23_col2,#T_a6bfb_row23_col3,#T_a6bfb_row23_col4,#T_a6bfb_row24_col0,#T_a6bfb_row24_col1,#T_a6bfb_row24_col2,#T_a6bfb_row24_col3,#T_a6bfb_row24_col4,#T_a6bfb_row25_col0,#T_a6bfb_row25_col1,#T_a6bfb_row25_col2,#T_a6bfb_row25_col3,#T_a6bfb_row25_col4,#T_a6bfb_row26_col0,#T_a6bfb_row26_col1,#T_a6bfb_row26_col2,#T_a6bfb_row26_col3,#T_a6bfb_row26_col4,#T_a6bfb_row27_col0,#T_a6bfb_row27_col1,#T_a6bfb_row27_col2,#T_a6bfb_row27_col3,#T_a6bfb_row27_col4,#T_a6bfb_row28_col0,#T_a6bfb_row28_col1,#T_a6bfb_row28_col2,#T_a6bfb_row28_col3,#T_a6bfb_row28_col4,#T_a6bfb_row29_col0,#T_a6bfb_row29_col1,#T_a6bfb_row29_col2,#T_a6bfb_row29_col3,#T_a6bfb_row29_col4,#T_a6bfb_row30_col0,#T_a6bfb_row30_col1,#T_a6bfb_row30_col2,#T_a6bfb_row30_col3,#T_a6bfb_row30_col4,#T_a6bfb_row31_col0,#T_a6bfb_row31_col1,#T_a6bfb_row31_col2,#T_a6bfb_row31_col3,#T_a6bfb_row31_col4,#T_a6bfb_row32_col0,#T_a6bfb_row32_col1,#T_a6bfb_row32_col2,#T_a6bfb_row32_col3,#T_a6bfb_row32_col4,#T_a6bfb_row33_col0,#T_a6bfb_row33_col1,#T_a6bfb_row33_col2,#T_a6bfb_row33_col3,#T_a6bfb_row33_col4,#T_a6bfb_row34_col0,#T_a6bfb_row34_col1,#T_a6bfb_row34_col2,#T_a6bfb_row34_col3,#T_a6bfb_row34_col4,#T_a6bfb_row35_col0,#T_a6bfb_row35_col1,#T_a6bfb_row35_col2,#T_a6bfb_row35_col3,#T_a6bfb_row35_col4,#T_a6bfb_row36_col0,#T_a6bfb_row36_col1,#T_a6bfb_row36_col2,#T_a6bfb_row36_col3,#T_a6bfb_row36_col4,#T_a6bfb_row37_col0,#T_a6bfb_row37_col1,#T_a6bfb_row37_col2,#T_a6bfb_row37_col3,#T_a6bfb_row37_col4,#T_a6bfb_row38_col0,#T_a6bfb_row38_col1,#T_a6bfb_row38_col2,#T_a6bfb_row38_col3,#T_a6bfb_row38_col4,#T_a6bfb_row39_col0,#T_a6bfb_row39_col1,#T_a6bfb_row39_col2,#T_a6bfb_row39_col3,#T_a6bfb_row39_col4,#T_a6bfb_row40_col0,#T_a6bfb_row40_col1,#T_a6bfb_r ...
